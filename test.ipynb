# %%
import numpy as np

# %%
a = range(0,10,4)

# %%
a
# Out:
# range(0, 10, 4)

# %%
range(0,10,4)
# Out:
# range(0, 10, 4)

# %%
np.arange(0,10,4)
# Out:
# array([0, 4, 8])

# %%
import numpy as np
aa = np.array([1,2,3,4,5,6,7,8])
aa = aa.reshape(-1,4,2)
print(aa.shape)
# Out:
# (1, 4, 2)

# %%
import numpy as np

a = np.array([[2,2,3],[1,2,3]])
np.delete(a,1,axis=0)
# Out:
# array([[2, 2, 3]])

# %%
import cv2
import numpy as np

# %%
import matplotlib.pyplot as plt
def FLD(image):
    # Create default Fast Line Detector class
    fld = cv2.ximgproc.createFastLineDetector()
    # Get line vectors from the image
    lines = fld.detect(image)
    # Draw lines on the image
    line_on_image = fld.drawSegments(image, lines)
    # Plot
    plt.imshow(line_on_image, interpolation='nearest', aspect='auto')
    plt.show()
    return line_on_image

# %%
img = cv2.imread("image/DSC00317.JPG")
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
FLD(img)
# Out:
# array([[[36, 36, 36],
#         [49, 49, 49],
#         [47, 47, 47],
#         ...,
#         [34, 34, 34],
#         [31, 31, 31],
#         [33, 33, 33]],
#
#        [[30, 30, 30],
#         [40, 40, 40],
#         [37, 37, 37],
#         ...,
#         [41, 41, 41],
#         [34, 34, 34],
#         [36, 36, 36]],
#
#        [[47, 47, 47],
#         [45, 45, 45],
#         [42, 42, 42],
#         ...,
#         [64, 64, 64],
#         [51, 51, 51],
#         [46, 46, 46]],
#
#        ...,
#        [[45, 45, 45],
#         [42, 42, 42],
#         [40, 40, 40],
#         ...,
#         [53, 53, 53],
#         [58, 58, 58],
#         [58, 58, 58]],
#
#        [[48, 48, 48],
#         [39, 39, 39],
#         [34, 34, 34],
#         ...,
#         [50, 50, 50],
#         [54, 54, 54],
#         [53, 53, 53]],
#
#        [[50, 50, 50],
#         [34, 34, 34],
#         [28, 28, 28],
#         ...,
#         [49, 49, 49],
#         [52, 52, 52],
#         [50, 50, 50]]], dtype=uint8)

# %%
b = np.array([1,2,3,4],dtype=np.float)
index = np.where(b>2)
index
# Out:
# (array([2, 3], dtype=int64),)

# %%
import cv2
import numpy as np
img = cv2.imread("image/DSC00317.JPG")
cv2.line(img, (10,10), (50, 50),(0, 0, 255), 1,4)

cv2.imshow("img",img)
cv2.waitKey(0)
# Out:
# -1

# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-
"""
@Time    : 2018-11-09 21：39
@Author  : jianjun.wang
@Email   : alanwang6584@gmail.com
"""

import numpy as np
import cv2 as cv
 
img = np.zeros((320, 320, 3), np.uint8) #生成一个空灰度图像
print (img.shape) # 输出：(320, 320, 3)

# 起点和终点的坐标
ptStart = (60, 60)
ptEnd = (260, 260)
point_color = (0, 255, 0) # BGR
thickness = 1 
lineType = 4
cv.line(img, ptStart, ptEnd, point_color, thickness, lineType)


ptStart = (260, 60)
ptEnd = (60, 260)
point_color = (0, 0, 255) # BGR
thickness = 1
lineType = 8
cv.line(img, ptStart, ptEnd, point_color, thickness, lineType)

cv.namedWindow("image")
cv.imshow('image', img)
cv.waitKey (10000) # 显示 10000 ms 即 10s 后消失
cv.destroyAllWindows()
# Out:
# (320, 320, 3)

# %%
    # #todo detect lines in source_warp image
    # # todo detected the 2 endpoint of the image
    # fld = cv2.ximgproc.createFastLineDetector()
    # # Get line vectors from the image
    # lines = fld.detect(src_warp_gray)
    # lines = np.squeeze(lines)
    # start = lines[:,:2]
    # end = lines[:,2:]
    # length = end-start
    # length = np.linalg.norm(length,axis=1,ord=2,keepdims=True)
    # length  = np.squeeze(length)
    # line_index = np.where(length>50)
    # line_index = line_index[0]
    # qualified_line = lines[line_index,:]
    # qualified_line = qualified_line.astype(np.int)
    # qualified_length = length[line_index]
    # qualified_length_divide_num = (qualified_length/10).astype(int)
    #
    # #
    #
    # for i in range(qualified_line.shape[0]):
    #     start = qualified_line[i,:2]
    #     end = qualified_line[i,2:4]
    #     cv2.line(src_warp,(start[0],start[1]),(end[0],end[1]),(0,255,0),thickness=2,lineType=8)
    # cv2.imshow("src_with_qualified_line",src_warp)
    # # todo sample to all of those lines
    # sample_lines = []
    # for i in range(qualified_line.shape[0]):
    #     u = qualified_length_divide_num[i]
    #     sample_line = []
    #     line = qualified_line[i]
    #     start = line[:2]
    #     end = line[2:]
    #     li = end-start
    #     for i in range(0,u+1):
    #         v = i/u*li+start
    #         sample_line.append(v)
    #     sample_line = np.array(sample_line)
    #     sample_lines.append(sample_line)
    #
    # # 绘制出直线上的采样点
    # for i_num in range(len(sample_lines)):
    #     for line_point in range(sample_lines[i_num].shape[0]):
    #         pts = sample_lines[i_num][line_point,:]
    #         cv2.circle(src_warp,(int(pts[0]),int(pts[1])),2,(0,0,255),thickness=2,lineType=8)
    # cv2.imshow("src_warp",src_warp)
    #
    # weight_lines = []
    # location_lines = []
    # for i in sample_lines:
    #     weight_line,location_line = bin_interpolate(i,mesh_boxes_src)
    #     weight_line = np.squeeze(weight_line)
    #     location_line = np.squeeze(location_line)
    #     weight_lines.append(weight_line)
    #     location_lines.append(location_line)
    # weight_lines = np.array(weight_lines)
    # location_lines = np.array(location_lines)
    # weight_lines = np.squeeze(weight_lines)
    # location_lines = np.squeeze(location_lines)

    # # 测试其是否是直线的情况
    # for i in range(len(weight_lines)):
    #     for j in range(1,weight_lines[i].shape[0]):
    #         u = j/(weight_lines[i].shape[0]-1)
    #         k = mesh_boxes_src[location_lines[i][j,0],location_lines[i][j,1]]*weight_lines[i][j,0] +\
    #             mesh_boxes_src[location_lines[i][j,0],location_lines[i][j,1]+1]*weight_lines[i][j,1] +\
    #             mesh_boxes_src[location_lines[i][j,0]+1,location_lines[i][j,1]+1]*weight_lines[i][j,2] + \
    #             mesh_boxes_src[location_lines[i][j,0]+1,location_lines[i][j,1]]*weight_lines[i][j,3]
    #
    #         start = mesh_boxes_src[location_lines[i][0,0],location_lines[i][0,1]]*weight_lines[i][0,0] +\
    #             mesh_boxes_src[location_lines[i][0,0],location_lines[i][0,1]+1]*weight_lines[i][0,1] +\
    #             mesh_boxes_src[location_lines[i][0,0]+1,location_lines[i][0,1]+1]*weight_lines[i][0,2] + \
    #             mesh_boxes_src[location_lines[i][0,0]+1,location_lines[i][0,1]]*weight_lines[i][0,3]
    #
    #         end = mesh_boxes_src[location_lines[i][weight_lines[i].shape[0]-1,0],location_lines[i][weight_lines[i].shape[0]-1,1]]*weight_lines[i][weight_lines[i].shape[0]-1,0] +\
    #             mesh_boxes_src[location_lines[i][weight_lines[i].shape[0]-1,0],location_lines[i][weight_lines[i].shape[0]-1,1]+1]*weight_lines[i][weight_lines[i].shape[0]-1,1] +\
    #             mesh_boxes_src[location_lines[i][weight_lines[i].shape[0]-1,0]+1,location_lines[i][weight_lines[i].shape[0]-1,1]+1]*weight_lines[i][weight_lines[i].shape[0]-1,2] + \
    #             mesh_boxes_src[location_lines[i][weight_lines[i].shape[0]-1,0]+1,location_lines[i][weight_lines[i].shape[0]-1,1]]*weight_lines[i][weight_lines[i].shape[0]-1,3]
    #
    #         # print(k-sample_lines[i,j,:],start-sample_lines[i,0,:],end-sample_lines[i,-1,:])
    #         # print(k - (start + (end-start)*u))
    #         print(k+(u-1)*start+(-u)*end,i)

    # temp = mesh_boxes_src-c
    #
    # for i in range(len(weight_lines)):
    #     for j in range(1,weight_lines[i].shape[0]):
    #         u = j/(weight_lines[i].shape[0]-1)
    #         k = c[location_lines[i][j,0],location_lines[i][j,1]]*weight_lines[i][j,0] +\
    #             c[location_lines[i][j,0],location_lines[i][j,1]+1]*weight_lines[i][j,1] +\
    #             c[location_lines[i][j,0]+1,location_lines[i][j,1]+1]*weight_lines[i][j,2] + \
    #             c[location_lines[i][j,0]+1,location_lines[i][j,1]]*weight_lines[i][j,3]
    #
    #         start = c[location_lines[i][0,0],location_lines[i][0,1]]*weight_lines[i][0,0] +\
    #             c[location_lines[i][0,0],location_lines[i][0,1]+1]*weight_lines[i][0,1] +\
    #             c[location_lines[i][0,0]+1,location_lines[i][0,1]+1]*weight_lines[i][0,2] + \
    #             c[location_lines[i][0,0]+1,location_lines[i][0,1]]*weight_lines[i][0,3]
    #
    #         end = c[location_lines[i][weight_lines[i].shape[0]-1,0],location_lines[i][weight_lines[i].shape[0]-1,1]]*weight_lines[i][weight_lines[i].shape[0]-1,0] +\
    #             c[location_lines[i][weight_lines[i].shape[0]-1,0],location_lines[i][weight_lines[i].shape[0]-1,1]+1]*weight_lines[i][weight_lines[i].shape[0]-1,1] +\
    #             c[location_lines[i][weight_lines[i].shape[0]-1,0]+1,location_lines[i][weight_lines[i].shape[0]-1,1]+1]*weight_lines[i][weight_lines[i].shape[0]-1,2] + \
    #             c[location_lines[i][weight_lines[i].shape[0]-1,0]+1,location_lines[i][weight_lines[i].shape[0]-1,1]]*weight_lines[i][weight_lines[i].shape[0]-1,3]
    #
    #         # print(k-sample_lines[i,j,:],start-sample_lines[i,0,:],end-sample_lines[i,-1,:])
    #         # print(k - (start + (end-start)*u))
    #         print(k+(u-1)*start+(-u)*end,i)
